# %%
import nltk
from nltk.chunk import ne_chunk, conlltags2tree, tree2conlltags
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from collections import Counter
from pprint import pprint
import en_core_web_sm
import pandas as pd
import spacy
from spacy import displacy

pd.set_option('display.max_rows', None)

# %%
## Step 2: Collect & Split Dataset
##################################
import text_preprocessor # Import Variables via Files from Directory
from text_preprocessor import training_text # Import Variables via Files from Directory
##################################
## Example text from Training Data
text = ' '.join(training_text)
print(text[0:250])
# Out:
# japan island country lying off the east coast of asia it consists of a great string of islands in a northeastsouthwest arc that stretches for approximately miles km through the western north pacific ocean nearly the entire land area is taken up by th

# %%
ne_tree = ne_chunk(pos_tag(training_text))
# print(ne_tree)

# %%
pos_tokenized_words = nltk.pos_tag(training_text)
pos_df = pd.DataFrame(pos_tokenized_words, columns = ['word','pos tag'])
pos_abbreviation_dict = {
             'CC':'coordinating conjunction',
             'CD':'cardinal digit',
             'DT':'determiner',
             'EX':'existential there',
             'FW':'foreign word',
             'IN':'preposition/subordinating conjunction',
             'JJ':'adjective (large)',
             'JJR':'adjective, comparative (larger)',
             'JJS':'adjective, superlative (largest)',
             'LS':'list market',
             'MD':'modal (could, will)',
             'NN':'noun, singular (cat, tree)',
             'NNS':'noun plural (desks)',
             'NNP':'proper noun, singular (sarah)',
             'NNPS':'proper noun, plural (indians or americans)',
             'PDT':'predeterminer (all, both, half)',
             'POS':'possessive ending (parent‘s)',
             'PRP':'personal pronoun (hers, herself, him, himself)',
             'PRP$':'possessive pronoun (her, his, mine, my, our)',
             'RB':'adverb (occasionally, swiftly)',
             'RBR':'adverb, comparative (greater)',
             'RBS':'adverb, superlative (biggest)',
             'RP':'particle (about)',
             'TO':'infinite marker (to)',
             'UH':'interjection (goodbye)',
             'VB':'verb (ask)',
             'VBG':'verb gerund (judging)',
             'VBD':'verb past tense (pleaded)',
             'VBN':'verb past participle (reunified)',
             'VBP':'verb, present tense not 3rd person singular (wrap)',
             'VBZ':'verb, present tense with 3rd person singular (bases)',
             'WDT':'wh-determiner (that, what)',
             'WP':'wh- pronoun (who)',
             'WRB':'wh- adverb (how)'
            }
pos_df['pos tag meaning'] = pos_df['pos tag'].map(pos_abbreviation_dict)
pos_df.head(25)
# Out:
#                   word pos tag  \
# 0                japan      NN
# 1               island     VBP
# 2              country      NN
# 3                lying     VBG
# 4                  off      RP
# 5                  the      DT
# 6                 east      JJ
# 7                coast      NN
# 8                   of      IN
# 9                 asia      NN
# 10                  it     PRP
# 11            consists     VBZ
# 12                  of      IN
# 13                   a      DT
# 14               great      JJ
# 15              string      NN
# 16                  of      IN
# 17             islands     NNS
# 18                  in      IN
# 19                   a      DT
# 20  northeastsouthwest      JJ
# 21                 arc      NN
# 22                that     WDT
# 23           stretches     VBZ
# 24                 for      IN
#
#                                       pos tag meaning
# 0                          noun, singular (cat, tree)
# 1   verb, present tense not 3rd person singular (w...
# 2                          noun, singular (cat, tree)
# 3                               verb gerund (judging)
# 4                                    particle (about)
# 5                                          determiner
# 6                                   adjective (large)
# 7                          noun, singular (cat, tree)
# 8               preposition/subordinating conjunction
# 9                          noun, singular (cat, tree)
# 10     personal pronoun (hers, herself, him, himself)
# 11  verb, present tense with 3rd person singular (...
# 12              preposition/subordinating conjunction
# 13                                         determiner
# 14                                  adjective (large)
# 15                         noun, singular (cat, tree)
# 16              preposition/subordinating conjunction
# 17                                noun plural (desks)
# 18              preposition/subordinating conjunction
# 19                                         determiner
# 20                                  adjective (large)
# 21                         noun, singular (cat, tree)
# 22                         wh-determiner (that, what)
# 23  verb, present tense with 3rd person singular (...
# 24              preposition/subordinating conjunction

# %%
nlp = en_core_web_sm.load()
doc = nlp(text)
array = [(X, X.ent_iob_, X.ent_type_) for X in doc]
df = pd.DataFrame(array, columns=['word','iob','entity type'])
description_dict = {'B':'beginning of an entity',
                    'I':'inside of an entity',
                    'O':'outside of an entity'}
df['iob description'] = df['iob'].map(description_dict)
description_dict = {'PERSON':'people, including fictional',
                    'NORP':'nationalities, religious or political groups',
                    'FAC':'buildings, airports, highways, bridges, etc',
                    'ORG':'companies, agencies, institutions, etc',
                    'GPE':'countries, cities, states',
                    'LOC':'non-GPE locations, mountain ranges, bodies of water',
                    'PRODUCT':'objects, vehicles, foods, etc (not services)',
                    'EVENT':'named hurricanes, battles, wars, sports events, etc',
                    'WORK_OF_ART':'titles of books, songs, etc',
                    'LAW':'named documents made into laws',
                    'LANGUAGE':'any named language',
                    'DATE':'absolute or relative dates or periods',
                    'TIME':'times smaller than a day',
                    'PERCENT':'percentage',
                    'MONEY':'monetary values',
                    'QUANTITY':'measurements, as of weight or distances',
                    'ORDINAL':'first, second, etc',
                    'CARDINAL':'numerals that do not fall under another type'
                   }
df['entity type description'] = df['entity type'].map(description_dict)
df.head(25)
# Out:
#                   word iob entity type         iob description  \
# 0                japan   B         ORG  beginning of an entity
# 1               island   I         ORG     inside of an entity
# 2              country   O                outside of an entity
# 3                lying   O                outside of an entity
# 4                  off   O                outside of an entity
# 5                  the   O                outside of an entity
# 6                 east   O                outside of an entity
# 7                coast   O                outside of an entity
# 8                   of   O                outside of an entity
# 9                 asia   B         LOC  beginning of an entity
# 10                  it   O                outside of an entity
# 11            consists   O                outside of an entity
# 12                  of   O                outside of an entity
# 13                   a   O                outside of an entity
# 14               great   O                outside of an entity
# 15              string   O                outside of an entity
# 16                  of   O                outside of an entity
# 17             islands   O                outside of an entity
# 18                  in   O                outside of an entity
# 19                   a   O                outside of an entity
# 20  northeastsouthwest   O                outside of an entity
# 21                 arc   O                outside of an entity
# 22                that   O                outside of an entity
# 23           stretches   O                outside of an entity
# 24                 for   O                outside of an entity
#
#                               entity type description
# 0              companies, agencies, institutions, etc
# 1              companies, agencies, institutions, etc
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   non-GPE locations, mountain ranges, bodies of ...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN

# %%
array = [(x.orth_,x.pos_, x.lemma_) for x in [y for y in nlp(str(text)) if not y.is_stop and y.pos_ != 'PUNCT']]
df = pd.DataFrame(array, columns=['word','type','lemma'])
df.head(25)
# Out:
#                   word   type            lemma
# 0                japan  PROPN            japan
# 1               island  PROPN           island
# 2              country   NOUN          country
# 3                lying   VERB              lie
# 4                 east  PROPN             east
# 5                coast  PROPN            coast
# 6                 asia  PROPN             asia
# 7             consists   VERB          consist
# 8                great    ADJ            great
# 9               string   NOUN           string
# 10             islands   NOUN           island
# 11  northeastsouthwest    ADJ  northeastsouthw
# 12                 arc   NOUN              arc
# 13           stretches   VERB          stretch
# 14       approximately    ADV    approximately
# 15               miles   NOUN             mile
# 16                  km   VERB               km
# 17             western    ADJ          western
# 18               north  PROPN            north
# 19             pacific  PROPN          pacific
# 20               ocean   NOUN            ocean
# 21              nearly    ADV           nearly
# 22              entire    ADJ           entire
# 23                land   NOUN             land
# 24                area   NOUN             area

# %%
displacy.render(nlp(str(text)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     japan island
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  country lying off the east coast of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     asia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  it consists of a great string of islands in a northeastsouthwest arc that stretches for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     approximately miles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  km through the western north pacific ocean nearly the entire land area is taken up by the countrys
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  main islands from north to south these are hokkaido hokkaido honshu honshu shikoku and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kyushu kyushu honshu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is the largest of the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  followed in size by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hokkaido kyushu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shikoku
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  in addition there are numerous smaller islands the major groups of which are the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ryukyu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  nansei islands including the island of okinawa to the south and west of kyushu and the izu bonin ogasawara and volcano kazan islands to the south and east of central honshu
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the national capital tokyo tokyo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in eastcentral honshu is one of the worlds most populous cities the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     japanese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  landscape is rugged with more than fourfifths of the land surface consisting of mountains there are many active and dormant volcanoes including
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mount fuji
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  fujisan which at an elevation of feet metres is japans highest mountain abundant precipitation and the generally mild temperatures throughout most of the country have produced a lush vegetation cover and despite the mountainous terrain and generally poor soils have made it possible to raise a variety of crops
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     japan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has a large and to a great extent ethnically homogeneous population which is heavily concentrated in the lowlying areas along
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the pacific coast
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  of honshu complexity and contrast are the keynotes of life in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     japan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  -- a country possessing an intricate and ancient cultural tradition yet one that since has emerged as one of the worlds most economically and technologically advanced societies heavy emphasis is placed on education and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     japan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is one of the worlds most literate countries tension between old and new is apparent in all phases of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     japanese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  life a characteristic sensitivity to natural beauty and a concern with form and balance are evident in such cities as
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kyoto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nara
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as well as in japans ubiquitous gardens even in the countryside however the impact of rapid westernization is evident in many aspects of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     japanese
#     <span style="font-size: 0.8em; font-wei

# %%
example_sentence = 'European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices'
sample = nltk.word_tokenize(example_sentence)
sample = nltk.pos_tag(sample)
pattern = 'Noun Phrase: {<DT>?<JJ>*<NN>}'
NPChunker = nltk.RegexpParser(pattern)
result = NPChunker.parse(sample)
# result.draw()

# %%
displacy.render(nlp(str(text)), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d25368d45a82446f915b93f21fd7dc35-0" class="displacy" width="76010" height="857.0" direction="ltr" style="max-width: none; height: 857.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">japan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">island</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">country</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">lying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">off</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">east</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">coast</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">asia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">consists</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">great</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">string</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">islands</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">northeastsouthwest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">arc</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">stretches</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">approximately</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">miles</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">km</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">through</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">western</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColo
