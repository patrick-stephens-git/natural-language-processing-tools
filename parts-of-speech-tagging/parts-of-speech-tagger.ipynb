# %%
import pandas as pd
import string
import nltk
import re

pd.set_option('display.max_rows', None)

# %%
## Import Training Data (Text Corpus):
with open('training-text.txt', encoding='utf-8') as input_file:
    training_text = input_file.read()
    
print(training_text)
# Out:
# Music theory is the study of the practices and possibilities of music. The Oxford Companion to Music describes three interrelated uses of the term "music theory". The first is the "rudiments", that are needed to understand music notation (key signatures, time signatures, and rhythmic notation); the second is learning scholars' views on music from antiquity to the present; the third is a sub-topic of musicology that "seeks to define processes and general principles in music". The musicological approach to theory differs from music analysis "in that it takes as its starting-point not the individual work or performance but the fundamental materials from which it is built."[1]
#
# Music theory is frequently concerned with describing how musicians and composers make music, including tuning systems and composition methods among other topics. Because of the ever-expanding conception of what constitutes music, a more inclusive definition could be the consideration of any sonic phenomena, including silence. This is not an absolute guideline, however; for example, the study of "music" in the Quadrivium liberal arts university curriculum, that was common in medieval Europe, was an abstract system of proportions that was carefully studied at a distance from actual musical practice.[n 1] But this medieval discipline became the basis for tuning systems in later centuries and is generally included in modern scholarship on the history of music theory.[n 2]
#
# Music theory as a practical discipline encompasses the methods and concepts that composers and other musicians use in creating music. The development, preservation, and transmission of music theory in this sense may be found in oral and written music-making traditions, musical instruments, and other artifacts. For example, ancient instruments from prehistoric sites around the world reveal details about the music they produced and potentially something of the musical theory that might have been used by their makers. In ancient and living cultures around the world, the deep and long roots of music theory are visible in instruments, oral traditions, and current music-making. Many cultures have also considered music theory in more formal ways such as written treatises and music notation. Practical and scholarly traditions overlap, as many practical treatises about music place themselves within a tradition of other treatises, which are cited regularly just as scholarly writing cites earlier research.
#
# Music is composed of aural phenomena; "music theory" considers how those phenomena apply in music. Music theory considers melody, rhythm, counterpoint, harmony, form, tonal systems, scales, tuning, intervals, consonance, dissonance, durational proportions, the acoustics of pitch systems, composition, performance, orchestration, ornamentation, improvisation, electronic sound production, etc.[27]
#
# Pitch is the lowness or highness of a tone, for example the difference between middle C and a higher C. The frequency of the sound waves producing a pitch can be measured precisely, but the perception of pitch is more complex because single notes from natural sources are usually a complex mix of many frequencies. Accordingly, theorists often describe pitch as a subjective sensation rather than an objective measurement of sound.[28]
#
# Specific frequencies are often assigned letter names. Today most orchestras assign concert A (the A above middle C on the piano) to the frequency of 440 Hz. This assignment is somewhat arbitrary; for example, in 1859 France, the same A was tuned to 435 Hz. Such differences can have a noticeable effect on the timbre of instruments and other phenomena. Thus, in historically informed performance of older music, tuning is often set to match the tuning used in the period when it was written. Additionally, many cultures do not attempt to standardize pitch, often considering that it should be allowed to vary depending on genre, style, mood, etc.
#
# The difference in pitch between two notes is called an interval. The most basic interval is the unison, which is simply two notes of the same pitch. The octave interval is two pitches that are either double or half the frequency of one another. The unique characteristics of octaves gave rise to the concept of pitch class: pitches of the same letter name that occur in different octaves may be grouped into a single "class" by ignoring the difference in octave. For example, a high C and a low C are members of the same pitch class—the class that contains all C's. [29]
#
# Musical tuning systems, or temperaments, determine the precise size of intervals. Tuning systems vary widely within and between world cultures. In Western culture, there have long been several competing tuning systems, all with different qualities. Internationally, the system known as equal temperament is most commonly used today because it is considered the most satisfactory compromise that allows instruments of fixed tuning (e.g. the piano) to sound acceptably in tune in all keys.
#
# Notes can be arranged in a variety of scales and modes. Western music theory generally divides the octave into a series of twelve pitches, called a chromatic scale, within which the interval between adjacent tones is called a half step, or semitone. Selecting tones from this set of 12 and arranging them in patterns of semitones and whole tones creates other scales.[30]
#
# Musical notation is the written or symbolized representation of music. This is most often achieved by the use of commonly understood graphic symbols and written verbal instructions and their abbreviations. There are many systems of music notation from different cultures and different ages. Traditional Western notation evolved during the Middle Ages and remains an area of experimentation and innovation.[69]In the 2000s, computer file formats have become important as well.[70] Spoken language and hand signs are also used to symbolically represent music, primarily in teaching.
#
# In standard Western music notation, tones are represented graphically by symbols (notes) placed on a staff or staves, the vertical axis corresponding to pitch and the horizontal axis corresponding to time. Note head shapes, stems, flags, ties and dots are used to indicate duration. Additional symbols indicate keys, dynamics, accents, rests, etc. Verbal instructions from the conductor are often used to indicate tempo, technique, and other aspects.
#
# In Western music, a range of different music notation systems are used. In Western Classical music, conductors use printed scores that show all of the instruments' parts and orchestra members read parts with their musical lines written out. In popular styles of music, much less of the music may be notated. A rock band may go into a recording session with just a handwritten chord chart indicating the song's chord progression using chord names (e.g., C major, D minor, G7, etc.). All of the chord voicings, rhythms and accompaniment figures are improvised by the band members.
#
# Japan (Japanese: 日本, Nippon or Nihon,[nb 1] and formally 日本国, Nihonkoku[nb 2]) is an island country in East Asia. It is situated in the northwest Pacific Ocean, and is bordered on the west by the Sea of Japan, while extending from the Sea of Okhotsk in the north toward the East China Sea, Philippine Sea, and Taiwan in the south. Japan is a part of the Ring of Fire, and spans an archipelago of 6852 islands covering 377,975 square kilometers (145,937 sq mi); the five main islands are Hokkaido, Honshu (the "mainland"), Shikoku, Kyushu, and Okinawa. Tokyo is the nation's capital and largest city, followed by Yokohama, Osaka, Nagoya, Sapporo, Fukuoka, Kobe, and Kyoto.
#
# Japan is the eleventh most populous country in the world, as well as one of the most densely populated and urbanized. About three-fourths of the country's terrain is mountainous, concentrating its population of 125.5 million on narrow coastal plains. Japan is divided into 47 administrative prefectures and eight traditional regions. The Greater Tokyo Area is the most populous metropolitan area in the world, with more than 37.4 million residents.
#
# Japan has been inhabited since the Upper Paleolithic period (30,000 BC), though the first written mention of the archipelago appears in a Chinese chronicle (the Book of Han) finished in the 2nd century AD. Between the 4th and 9th centuries, the kingdoms of Japan became unified under an emperor and the imperial court based in Heian-kyō. Beginning in the 12th century, political power was held by a series of military dictators (shōgun) and feudal lords (daimyō) and enforced by a class of warrior nobility (samurai). After a century-long period of civil war, the country was reunified in 1603 under the Tokugawa shogunate, which enacted an isolationist foreign policy. In 1854, a United States fleet forced Japan to open trade to the West, which led to the end of the shogunate and the restoration of imperial power in 1868. In the Meiji period, the Empire of Japan adopted a Western-modeled constitution and pursued a program of industrialization and modernization. Amidst a rise in militarism and overseas colonization, Japan invaded China in 1937 and entered World War II as an Axis power in 1941. After suffering defeat in the Pacific War and two atomic bombings, Japan surrendered in 1945 and came under a seven-year Allied occupation, during which it adopted a new constitution and began a military alliance with the United States. Under the 1947 constitution, Japan has maintained a unitary parliamentary constitutional monarchy with a bicameral legislature, the National Diet.
#
# Japan is a highly developed country, and a great power in global politics. Its economy is the world's third-largest by nominal GDP and the fourth-largest by PPP. Although Japan has renounced its right to declare war, the country maintains Self-Defense Forces that rank as one of the world's strongest militaries. After World War II, Japan experienced record growth in an economic miracle, becoming the second-largest economy in the world by 1972 but has stagnated since 1995 in what is referred to as the Lost Decades. Japan has the world's highest life expectancy, though it is experiencing a decline in population. A global leader in the automotive, robotics and electronics industries, the country has made significant contributions to science and technology. The culture of Japan is well known around the world, including its art, cuisine, music, and popular culture, which encompasses prominent comic, animation and video game industries. It is a member of numerous international organizations, including the United Nations (since 1956), OECD, G20 and Group of Seven.
#
# The name for Japan in Japanese is written using the kanji 日本 and is pronounced Nippon or Nihon.[9] Before 日本 was adopted in the early 8th century, the country was known in China as Wa (倭, changed in Japan around 757 to 和) and in Japan by the endonym Yamato.[10] Nippon, the original Sino-Japanese reading of the characters, is favored for official uses, including on banknotes and postage stamps.[9] Nihon is typically used in everyday speech and reflects shifts in Japanese phonology during the Edo period.[10] The characters 日本 mean "sun origin",[9] which is the source of the popular Western epithet "Land of the Rising Sun".[11]
#
# The name "Japan" is based on Chinese pronunciations of 日本 and was introduced to European languages through early trade. In the 13th century, Marco Polo recorded the early Mandarin or Wu Chinese pronunciation of the characters 日本國 as Cipangu.[12] The old Malay name for Japan, Japang or Japun, was borrowed from a southern coastal Chinese dialect and encountered by Portuguese traders in Southeast Asia, who brought the word to Europe in the early 16th century.[13] The first version of the name in English appears in a book published in 1577, which spelled the name as Giapan in a translation of a 1565 Portuguese letter.[14][15]
#
# A Paleolithic culture from around 30,000 BC constitutes the first known habitation of the islands of Japan.[16] This was followed from around 14,500 BC (the start of the Jōmon period) by a Mesolithic to Neolithic semi-sedentary hunter-gatherer culture characterized by pit dwelling and rudimentary agriculture.[17] Clay vessels from the period are among the oldest surviving examples of pottery.[18] From around 1000 BC, Yayoi people began to enter the archipelago from Kyushu, intermingling with the Jōmon;[19] the Yayoi period saw the introduction of practices including wet-rice farming,[20] a new style of pottery,[21] and metallurgy from China and Korea.[22] According to legend, Emperor Jimmu (grandson of Amaterasu) founded a kingdom in central Japan in 660 BC, beginning a continuous imperial line.[23]
#
# Japan first appears in written history in the Chinese Book of Han, completed in 111 AD. Buddhism was introduced to Japan from Baekje (a Korean kingdom) in 552, but the development of Japanese Buddhism was primarily influenced by China.[24] Despite early resistance, Buddhism was promoted by the ruling class, including figures like Prince Shōtoku, and gained widespread acceptance beginning in the Asuka period (592–710).[25]
#
# The far-reaching Taika Reforms in 645 nationalized all land in Japan, to be distributed equally among cultivators, and ordered the compilation of a household registry as the basis for a new system of taxation.[26] The Jinshin War of 672, a bloody conflict between Prince Ōama and his nephew Prince Ōtomo, became a major catalyst for further administrative reforms.[27] These reforms culminated with the promulgation of the Taihō Code, which consolidated existing statutes and established the structure of the central and subordinate local governments.[26] These legal reforms created the ritsuryō state, a system of Chinese-style centralized government that remained in place for half a millennium.[27]
#
# The Nara period (710–784) marked the emergence of a Japanese state centered on the Imperial Court in Heijō-kyō (modern Nara). The period is characterized by the appearance of a nascent literary culture with the completion of the Kojiki (712) and Nihon Shoki (720), as well as the development of Buddhist-inspired artwork and architecture.[28][29] A smallpox epidemic in 735–737 is believed to have killed as much as one-third of Japan's population.[29][30] In 784, Emperor Kanmu moved the capital, settling on Heian-kyō (modern-day Kyoto) in 794.[29] This marked the beginning of the Heian period (794–1185), during which a distinctly indigenous Japanese culture emerged. Murasaki Shikibu's The Tale of Genji and the lyrics of Japan's national anthem "Kimigayo" were written during this time.[31]
#
# Japan's feudal era was characterized by the emergence and dominance of a ruling class of warriors, the samurai.[32] In 1185, following the defeat of the Taira clan in the Genpei War, samurai Minamoto no Yoritomo established a military government at Kamakura.[33] After Yoritomo's death, the Hōjō clan came to power as regents for the shōgun.[29] The Zen school of Buddhism was introduced from China in the Kamakura period (1185–1333) and became popular among the samurai class.[34] The Kamakura shogunate repelled Mongol invasions in 1274 and 1281 but was eventually overthrown by Emperor Go-Daigo.[29] Go-Daigo was defeated by Ashikaga Takauji in 1336, beginning the Muromachi period (1336–1573).[35] The succeeding Ashikaga shogunate failed to control the feudal warlords (daimyō) and a civil war began in 1467, opening the century-long Sengoku period ("Warring States").[36]
#
# During the 16th century, Portuguese traders and Jesuit missionaries reached Japan for the first time, initiating direct commercial and cultural exchange between Japan and the West.[29][37] Oda Nobunaga used European technology and firearms to conquer many other daimyō;[38] his consolidation of power began what was known as the Azuchi–Momoyama period.[39] After the death of Nobunaga in 1582, his successor, Toyotomi Hideyoshi, unified the nation in the early 1590s and launched two unsuccessful invasions of Korea in 1592 and 1597.[29]
#
# Tokugawa Ieyasu served as regent for Hideyoshi's son Toyotomi Hideyori and used his position to gain political and military support.[40] When open war broke out, Ieyasu defeated rival clans in the Battle of Sekigahara in 1600. He was appointed shōgun by Emperor Go-Yōzei in 1603 and established the Tokugawa shogunate at Edo (modern Tokyo).[41] The shogunate enacted measures including buke shohatto, as a code of conduct to control the autonomous daimyō,[42] and in 1639 the isolationist sakoku ("closed country") policy that spanned the two and a half centuries of tenuous political unity known as the Edo period (1603–1868).[41][43] Modern Japan's economic growth began in this period, resulting in roads and water transportation routes, as well as financial instruments such as futures contracts, banking and insurance of the Osaka rice brokers.[44] The study of Western sciences (rangaku) continued through contact with the Dutch enclave in Nagasaki.[41] The Edo period gave rise to kokugaku ("national studies"), the study of Japan by the Japanese.[45]
#
# In 1854, Commodore Matthew C. Perry and the "Black Ships" of the United States Navy forced the opening of Japan to the outside world with the Convention of Kanagawa.[41] Subsequent similar treaties with other Western countries brought economic and political crises.[41] The resignation of the shōgun led to the Boshin War and the establishment of a centralized state nominally unified under the emperor (the Meiji Restoration).[46] Adopting Western political, judicial, and military institutions, the Cabinet organized the Privy Council, introduced the Meiji Constitution (29 November 1890), and assembled the Imperial Diet.[47] During the Meiji period (1868–1912), the Empire of Japan emerged as the most developed nation in Asia and as an industrialized world power that pursued military conflict to expand its sphere of influence.[48][49][50] After victories in the First Sino-Japanese War (1894–1895) and the Russo-Japanese War (1904–1905), Japan gained control of Taiwan, Korea and the southern half of Sakhalin.[51][47] The Japanese population doubled from 35 million in 1873 to 70 million by 1935, with a significant shift to urbanization.[52][53]
#
# The early 20th century saw a period of Taishō democracy (1912–1926) overshadowed by increasing expansionism and militarization.[54][55] World War I allowed Japan, which joined the side of the victorious Allies, to capture German possessions in the Pacific and in China.[55] The 1920s saw a political shift towards statism, a period of lawlessness following the 1923 Great Tokyo Earthquake, the passing of laws against political dissent, and a series of attempted coups.[53][56][57] This process accelerated during the 1930s, spawning a number of radical nationalist groups that shared a hostility to liberal democracy and a dedication to expansion in Asia. In 1931, Japan invaded and occupied Manchuria; following international condemnation of the occupation, it resigned from the League of Nations two years later.[58] In 1936, Japan signed the Anti-Comintern Pact with Nazi Germany; the 1940 Tripartite Pact made it one of the Axis Powers.[53]
#
#
# Japan's imperial ambitions ended on September 2, 1945, with the country's surrender to the Allies.
# The Empire of Japan invaded other parts of China in 1937, precipitating the Second Sino-Japanese War (1937–1945).[59] In 1940, the Empire invaded French Indochina, after which the United States placed an oil embargo on Japan.[53][60] On December 7–8, 1941, Japanese forces carried out surprise attacks on Pearl Harbor, as well as on British forces in Malaya, Singapore, and Hong Kong, among others, beginning World War II in the Pacific.[61] Throughout areas occupied by Japan during the war, numerous abuses were committed against local inhabitants, with many forced into sexual slavery.[62] After Allied victories during the next four years, which culminated in the Soviet invasion of Manchuria and the atomic bombings of Hiroshima and Nagasaki in 1945, Japan agreed to an unconditional surrender.[63] The war cost Japan its colonies and millions of lives.[53] The Allies (led by the United States) repatriated millions of Japanese settlers from their former colonies and military camps throughout Asia, largely eliminating the Japanese empire and its influence over the territories it conquered.[64][65] The Allies convened the International Military Tribunal for the Far East to prosecute Japanese leaders for war crimes.[65]
#
# In 1947, Japan adopted a new constitution emphasizing liberal democratic practices.[65] The Allied occupation ended with the Treaty of San Francisco in 1952,[66] and Japan was granted membership in the United Nations in 1956.[65] A period of record growth propelled Japan to become the second-largest economy in the world;[65] this ended in the mid-1990s after the popping of an asset price bubble, beginning the "Lost Decade".[67] On March 11, 2011, Japan suffered one of the largest earthquakes in its recorded history, triggering the Fukushima Daiichi nuclear disaster.[68] On May 1, 2019, after the historic abdication of Emperor Akihito, his son Naruhito became Emperor, beginning the Reiwa era.[69]
#
# Japan comprises 6852 islands extending along the Pacific coast of Asia. It stretches over 3000 km (1900 mi) northeast–southwest from the Sea of Okhotsk to the East China Sea.[70][71] The country's five main islands, from north to south, are Hokkaido, Honshu, Shikoku, Kyushu and Okinawa.[72] The Ryukyu Islands, which include Okinawa, are a chain to the south of Kyushu. The Nanpō Islands are south and east of the main islands of Japan. Together they are often known as the Japanese archipelago.[73] As of 2019, Japan's territory is 377,975.24 km2 (145,937.06 sq mi).[1] Japan has the sixth-longest coastline in the world at 29,751 km (18,486 mi). Because of its far-flung outlying islands, Japan has the eighth largest Exclusive Economic Zone in the world, covering 4,470,000 km2 (1,730,000 sq mi).[74][75]
#
# The Japanese archipelago is 67% forests and 14% agricultural.[76] The primarily rugged and mountainous terrain is restricted for habitation.[77] Thus the habitable zones, mainly in the coastal areas, have very high population densities: Japan is the 40th most densely populated country.[78][79] Honshu has the highest population density at 450 persons/km² (1200/sq mi) as of 2010, while Hokkaido has the lowest density of 64.5 persons/km² as of 2016.[80] As of 2014, approximately 0.5% of Japan's total area is reclaimed land (umetatechi).[81] Lake Biwa is an ancient lake and the country's largest freshwater lake.[82]

# %%
## Clean Training Data: (Preprocessing)
## Remove Punctuation Characters:
training_text = training_text.translate(str.maketrans('', '', string.punctuation))
## Remove Line Breaks:
training_text = training_text.replace('\n','')
## Remove Numerical Characters:
training_text = re.sub(r'[0-9]+', '', training_text)
## Lowercase Characters:
training_text = training_text.lower()
## Split String into List:
training_text_word_list = training_text.split()
print(training_text_word_list)
# Out:
# ['music', 'theory', 'is', 'the', 'study', 'of', 'the', 'practices', 'and', 'possibilities', 'of', 'music', 'the', 'oxford', 'companion', 'to', 'music', 'describes', 'three', 'interrelated', 'uses', 'of', 'the', 'term', 'music', 'theory', 'the', 'first', 'is', 'the', 'rudiments', 'that', 'are', 'needed', 'to', 'understand', 'music', 'notation', 'key', 'signatures', 'time', 'signatures', 'and', 'rhythmic', 'notation', 'the', 'second', 'is', 'learning', 'scholars', 'views', 'on', 'music', 'from', 'antiquity', 'to', 'the', 'present', 'the', 'third', 'is', 'a', 'subtopic', 'of', 'musicology', 'that', 'seeks', 'to', 'define', 'processes', 'and', 'general', 'principles', 'in', 'music', 'the', 'musicological', 'approach', 'to', 'theory', 'differs', 'from', 'music', 'analysis', 'in', 'that', 'it', 'takes', 'as', 'its', 'startingpoint', 'not', 'the', 'individual', 'work', 'or', 'performance', 'but', 'the', 'fundamental', 'materials', 'from', 'which', 'it', 'is', 'builtmusic', 'theory', 'is', 'frequently', 'concerned', 'with', 'describing', 'how', 'musicians', 'and', 'composers', 'make', 'music', 'including', 'tuning', 'systems', 'and', 'composition', 'methods', 'among', 'other', 'topics', 'because', 'of', 'the', 'everexpanding', 'conception', 'of', 'what', 'constitutes', 'music', 'a', 'more', 'inclusive', 'definition', 'could', 'be', 'the', 'consideration', 'of', 'any', 'sonic', 'phenomena', 'including', 'silence', 'this', 'is', 'not', 'an', 'absolute', 'guideline', 'however', 'for', 'example', 'the', 'study', 'of', 'music', 'in', 'the', 'quadrivium', 'liberal', 'arts', 'university', 'curriculum', 'that', 'was', 'common', 'in', 'medieval', 'europe', 'was', 'an', 'abstract', 'system', 'of', 'proportions', 'that', 'was', 'carefully', 'studied', 'at', 'a', 'distance', 'from', 'actual', 'musical', 'practicen', 'but', 'this', 'medieval', 'discipline', 'became', 'the', 'basis', 'for', 'tuning', 'systems', 'in', 'later', 'centuries', 'and', 'is', 'generally', 'included', 'in', 'modern', 'scholarship', 'on', 'the', 'history', 'of', 'music', 'theoryn', 'music', 'theory', 'as', 'a', 'practical', 'discipline', 'encompasses', 'the', 'methods', 'and', 'concepts', 'that', 'composers', 'and', 'other', 'musicians', 'use', 'in', 'creating', 'music', 'the', 'development', 'preservation', 'and', 'transmission', 'of', 'music', 'theory', 'in', 'this', 'sense', 'may', 'be', 'found', 'in', 'oral', 'and', 'written', 'musicmaking', 'traditions', 'musical', 'instruments', 'and', 'other', 'artifacts', 'for', 'example', 'ancient', 'instruments', 'from', 'prehistoric', 'sites', 'around', 'the', 'world', 'reveal', 'details', 'about', 'the', 'music', 'they', 'produced', 'and', 'potentially', 'something', 'of', 'the', 'musical', 'theory', 'that', 'might', 'have', 'been', 'used', 'by', 'their', 'makers', 'in', 'ancient', 'and', 'living', 'cultures', 'around', 'the', 'world', 'the', 'deep', 'and', 'long', 'roots', 'of', 'music', 'theory', 'are', 'visible', 'in', 'instruments', 'oral', 'traditions', 'and', 'current', 'musicmaking', 'many', 'cultures', 'have', 'also', 'considered', 'music', 'theory', 'in', 'more', 'formal', 'ways', 'such', 'as', 'written', 'treatises', 'and', 'music', 'notation', 'practical', 'and', 'scholarly', 'traditions', 'overlap', 'as', 'many', 'practical', 'treatises', 'about', 'music', 'place', 'themselves', 'within', 'a', 'tradition', 'of', 'other', 'treatises', 'which', 'are', 'cited', 'regularly', 'just', 'as', 'scholarly', 'writing', 'cites', 'earlier', 'researchmusic', 'is', 'composed', 'of', 'aural', 'phenomena', 'music', 'theory', 'considers', 'how', 'those', 'phenomena', 'apply', 'in', 'music', 'music', 'theory', 'considers', 'melody', 'rhythm', 'counterpoint', 'harmony', 'form', 'tonal', 'systems', 'scales', 'tuning', 'intervals', 'consonance', 'dissonance', 'durational', 'proportions', 'the', 'acoustics', 'of', 'pitch', 'systems', 'composition', 'performance', 'orchestration', 'ornamentation', 'improvisation', 'electronic', 'sound', 'pro ...

# %%
pos_tokenized_words = nltk.pos_tag(training_text_word_list)
print(pos_tokenized_words)
# Out:
# [('music', 'NN'), ('theory', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('study', 'NN'), ('of', 'IN'), ('the', 'DT'), ('practices', 'NNS'), ('and', 'CC'), ('possibilities', 'NNS'), ('of', 'IN'), ('music', 'NN'), ('the', 'DT'), ('oxford', 'NN'), ('companion', 'NN'), ('to', 'TO'), ('music', 'NN'), ('describes', 'NNS'), ('three', 'CD'), ('interrelated', 'JJ'), ('uses', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('term', 'NN'), ('music', 'NN'), ('theory', 'NN'), ('the', 'DT'), ('first', 'JJ'), ('is', 'VBZ'), ('the', 'DT'), ('rudiments', 'NNS'), ('that', 'WDT'), ('are', 'VBP'), ('needed', 'VBN'), ('to', 'TO'), ('understand', 'VB'), ('music', 'NN'), ('notation', 'NN'), ('key', 'JJ'), ('signatures', 'NNS'), ('time', 'NN'), ('signatures', 'NNS'), ('and', 'CC'), ('rhythmic', 'JJ'), ('notation', 'NN'), ('the', 'DT'), ('second', 'JJ'), ('is', 'VBZ'), ('learning', 'VBG'), ('scholars', 'NNS'), ('views', 'NNS'), ('on', 'IN'), ('music', 'NN'), ('from', 'IN'), ('antiquity', 'NN'), ('to', 'TO'), ('the', 'DT'), ('present', 'JJ'), ('the', 'DT'), ('third', 'JJ'), ('is', 'VBZ'), ('a', 'DT'), ('subtopic', 'NN'), ('of', 'IN'), ('musicology', 'NN'), ('that', 'WDT'), ('seeks', 'VBZ'), ('to', 'TO'), ('define', 'VB'), ('processes', 'NNS'), ('and', 'CC'), ('general', 'JJ'), ('principles', 'NNS'), ('in', 'IN'), ('music', 'NN'), ('the', 'DT'), ('musicological', 'JJ'), ('approach', 'NN'), ('to', 'TO'), ('theory', 'JJ'), ('differs', 'NNS'), ('from', 'IN'), ('music', 'NN'), ('analysis', 'NN'), ('in', 'IN'), ('that', 'DT'), ('it', 'PRP'), ('takes', 'VBZ'), ('as', 'IN'), ('its', 'PRP$'), ('startingpoint', 'NN'), ('not', 'RB'), ('the', 'DT'), ('individual', 'JJ'), ('work', 'NN'), ('or', 'CC'), ('performance', 'NN'), ('but', 'CC'), ('the', 'DT'), ('fundamental', 'JJ'), ('materials', 'NNS'), ('from', 'IN'), ('which', 'WDT'), ('it', 'PRP'), ('is', 'VBZ'), ('builtmusic', 'JJ'), ('theory', 'NN'), ('is', 'VBZ'), ('frequently', 'RB'), ('concerned', 'VBN'), ('with', 'IN'), ('describing', 'VBG'), ('how', 'WRB'), ('musicians', 'NNS'), ('and', 'CC'), ('composers', 'NNS'), ('make', 'VBP'), ('music', 'NN'), ('including', 'VBG'), ('tuning', 'VBG'), ('systems', 'NNS'), ('and', 'CC'), ('composition', 'NN'), ('methods', 'NNS'), ('among', 'IN'), ('other', 'JJ'), ('topics', 'NNS'), ('because', 'IN'), ('of', 'IN'), ('the', 'DT'), ('everexpanding', 'VBG'), ('conception', 'NN'), ('of', 'IN'), ('what', 'WP'), ('constitutes', 'VBZ'), ('music', 'NN'), ('a', 'DT'), ('more', 'RBR'), ('inclusive', 'JJ'), ('definition', 'NN'), ('could', 'MD'), ('be', 'VB'), ('the', 'DT'), ('consideration', 'NN'), ('of', 'IN'), ('any', 'DT'), ('sonic', 'JJ'), ('phenomena', 'NNS'), ('including', 'VBG'), ('silence', 'NN'), ('this', 'DT'), ('is', 'VBZ'), ('not', 'RB'), ('an', 'DT'), ('absolute', 'NN'), ('guideline', 'NN'), ('however', 'RB'), ('for', 'IN'), ('example', 'NN'), ('the', 'DT'), ('study', 'NN'), ('of', 'IN'), ('music', 'NN'), ('in', 'IN'), ('the', 'DT'), ('quadrivium', 'NN'), ('liberal', 'JJ'), ('arts', 'NNS'), ('university', 'NN'), ('curriculum', 'NN'), ('that', 'WDT'), ('was', 'VBD'), ('common', 'JJ'), ('in', 'IN'), ('medieval', 'JJ'), ('europe', 'NN'), ('was', 'VBD'), ('an', 'DT'), ('abstract', 'JJ'), ('system', 'NN'), ('of', 'IN'), ('proportions', 'NNS'), ('that', 'WDT'), ('was', 'VBD'), ('carefully', 'RB'), ('studied', 'VBN'), ('at', 'IN'), ('a', 'DT'), ('distance', 'NN'), ('from', 'IN'), ('actual', 'JJ'), ('musical', 'JJ'), ('practicen', 'NN'), ('but', 'CC'), ('this', 'DT'), ('medieval', 'JJ'), ('discipline', 'NN'), ('became', 'VBD'), ('the', 'DT'), ('basis', 'NN'), ('for', 'IN'), ('tuning', 'VBG'), ('systems', 'NNS'), ('in', 'IN'), ('later', 'JJ'), ('centuries', 'NNS'), ('and', 'CC'), ('is', 'VBZ'), ('generally', 'RB'), ('included', 'VBN'), ('in', 'IN'), ('modern', 'JJ'), ('scholarship', 'NN'), ('on', 'IN'), ('the', 'DT'), ('history', 'NN'), ('of', 'IN'), ('music', 'NN'), ('theoryn', 'NN'), ('music', 'NN'), ('theory', 'NN'), ('as', 'IN'), ('a', 'DT'), ('practical', 'JJ'), ('discipline', 'NN'), ('encompass ...

# %%
pos_df = pd.DataFrame(pos_tokenized_words, columns = ['word','pos tag'])
pos_df.head()
# Out:
#      word pos tag
# 0   music      NN
# 1  theory      NN
# 2      is     VBZ
# 3     the      DT
# 4   study      NN

# %%
pos_abbreviation_dict = {
             'CC':'coordinating conjunction',
             'CD':'cardinal digit',
             'DT':'determiner',
             'EX':'existential there',
             'FW':'foreign word',
             'IN':'preposition/subordinating conjunction',
             'JJ':'This NLTK POS Tag is an adjective (large)',
             'JJR':'adjective, comparative (larger)',
             'JJS':'adjective, superlative (largest)',
             'LS':'list market',
             'MD':'modal (could, will)',
             'NN':'noun, singular (cat, tree)',
             'NNS':'noun plural (desks)',
             'NNP':'proper noun, singular (sarah)',
             'NNPS':'proper noun, plural (indians or americans)',
             'PDT':'predeterminer (all, both, half)',
             'POS':'possessive ending (parent‘s)',
             'PRP':'personal pronoun (hers, herself, him, himself)',
             'PRP$':'possessive pronoun (her, his, mine, my, our)',
             'RB':'adverb (occasionally, swiftly)',
             'RBR':'adverb, comparative (greater)',
             'RBS':'adverb, superlative (biggest)',
             'RP':'particle (about)',
             'TO':'infinite marker (to)',
             'UH':'interjection (goodbye)',
             'VB':'verb (ask)',
             'VBG':'verb gerund (judging)',
             'VBD':'verb past tense (pleaded)',
             'VBN':'verb past participle (reunified)',
             'VBP':'verb, present tense not 3rd person singular (wrap)',
             'VBZ':'verb, present tense with 3rd person singular (bases)',
             'WDT':'wh-determiner (that, what)',
             'WP':'wh- pronoun (who)',
             'WRB':'wh- adverb (how)'
            }

pos_df['pos tag meaning'] = pos_df['pos tag'].map(pos_abbreviation_dict)
pos_df
# Out:
#                      word pos tag  \
# 0                   music      NN
# 1                  theory      NN
# 2                      is     VBZ
# 3                     the      DT
# 4                   study      NN
# 5                      of      IN
# 6                     the      DT
# 7               practices     NNS
# 8                     and      CC
# 9           possibilities     NNS
# 10                     of      IN
# 11                  music      NN
# 12                    the      DT
# 13                 oxford      NN
# 14              companion      NN
# 15                     to      TO
# 16                  music      NN
# 17              describes     NNS
# 18                  three      CD
# 19           interrelated      JJ
# 20                   uses     NNS
# 21                     of      IN
# 22                    the      DT
# 23                   term      NN
# 24                  music      NN
# 25                 theory      NN
# 26                    the      DT
# 27                  first      JJ
# 28                     is     VBZ
# 29                    the      DT
# 30              rudiments     NNS
# 31                   that     WDT
# 32                    are     VBP
# 33                 needed     VBN
# 34                     to      TO
# 35             understand      VB
# 36                  music      NN
# 37               notation      NN
# 38                    key      JJ
# 39             signatures     NNS
# 40                   time      NN
# 41             signatures     NNS
# 42                    and      CC
# 43               rhythmic      JJ
# 44               notation      NN
# 45                    the      DT
# 46                 second      JJ
# 47                     is     VBZ
# 48               learning     VBG
# 49               scholars     NNS
# 50                  views     NNS
# 51                     on      IN
# 52                  music      NN
# 53                   from      IN
# 54              antiquity      NN
# 55                     to      TO
# 56                    the      DT
# 57                present      JJ
# 58                    the      DT
# 59                  third      JJ
# 60                     is     VBZ
# 61                      a      DT
# 62               subtopic      NN
# 63                     of      IN
# 64             musicology      NN
# 65                   that     WDT
# 66                  seeks     VBZ
# 67                     to      TO
# 68                 define      VB
# 69              processes     NNS
# 70                    and      CC
# 71                general      JJ
# 72             principles     NNS
# 73                     in      IN
# 74                  music      NN
# 75                    the      DT
# 76          musicological      JJ
# 77               approach      NN
# 78                     to      TO
# 79                 theory      JJ
# 80                differs     NNS
# 81                   from      IN
# 82                  music      NN
# 83               analysis      NN
# 84                     in      IN
# 85                   that      DT
# 86                     it     PRP
# 87                  takes     VBZ
# 88                     as      IN
# 89                    its    PRP$
# 90          startingpoint      NN
# 91                    not      RB
# 92                    the      DT
# 93             individual      JJ
# 94                   work      NN
# 95                     or      CC
# 96            performance      NN
# 97                    but      CC
# 98                    the      DT
# 99            fundamental      JJ
# 100             materials     NNS
# 101                  from      IN
# 102                 which     WDT
# 103                    it     PRP
# 104                    is     VBZ
# 105            builtmusic      JJ
# 106                theory      NN
# 107                    is     VBZ
# 108            frequently      RB
# 109             concerned     VBN
# 110                  with      IN
# 111            describing     VBG
# 112                   how     WRB
# 113             musicians     NNS
# 114                   and      CC
# 115             composers     NNS
# 116                  make     VBP
# 117                 music      NN
# 118             including     VBG
# 119                tuning     VBG
# 120               systems     NNS
# 121                   and      CC
# 122           composition      NN
# 123               methods     NNS
# 124                 among      IN
# 125                 other      JJ
# 126                topics     NNS
# 127               because      IN
# 128                    of      IN
# 129                   the      DT
# 130         everexpanding     VBG
# 131            conception      NN
# 132                    of      IN
# 133                  what      WP
# 134           constitutes     VBZ
# 135                 music      NN
# 136                     a      DT
# 137                  more     RBR
# 138             inclusive      JJ
# 139            definition      NN
# 140                 could      MD
# 141                    be      VB
# 142                   the      DT
# 143         consideration      NN
# 144                    of      IN
# 145                   any      DT
# 146                 sonic      JJ
# 147             phenomena     NNS
# 148             including     VBG
# 149               silence      NN
# 150                  this      DT
# 151                    is     VBZ
# 152                   not      RB
# 153                    an      DT
# 154              absolute      NN
# 155             guideline      NN
# 156               however      RB
# 157                   for      IN
# 158               example      NN
# 159                   the      DT
# 160                 study      NN
# 161                    of      IN
# 162                 music      NN
# 163                    in      IN
# 164                   the      DT
# 165            quadrivium      NN
# 166               liberal      JJ
# 167                  arts     NNS
# 168            university      NN
# 169            curriculum      NN
# 170                  that     WDT
# 171                   was     VBD
# 172                common      JJ
# 173                    in      IN
# 174              medieval      JJ
# 175                europe      NN
# 176                   was     VBD
# 177                    an      DT
# 178              abstract      JJ
# 179                system      NN
# 180                    of      IN
# 181           proportions     NNS
# 182                  that     WDT
# 183                   was     VBD
# 184             carefully      RB
# 185               studied     VBN
# 186                    at      IN
# 187                     a      DT
# 188              distance      NN
# 189                  from      IN
# 190                actual      JJ
# 191               musical      JJ
# 192             practicen      NN
# 193                   but      CC
# 194                  this      DT
# 195              medieval      JJ
# 196            discipline      NN
# 197                became     VBD
# 198                   the      DT
# 199                 basis      NN
# 200                   for      IN
# 201                tuning     VBG
# 202               systems     NNS
# 203                    in      IN
# 204                 later      JJ
# 205             centuries     NNS
# 206                   and      CC
# 207                    is     VBZ
# 208             generally      RB
# 209              included     VBN
# 210                    in      IN
# 211                modern      JJ
# 212           scholarship      NN
# 213                    on      IN
# 214                   the      DT
# 215               history      NN
# 216                    of      IN
# 217                 music      NN
# 218               theoryn      NN
# 219                 music      NN
# 220                theory      NN
# 221                    as      IN
# 222                     a      DT
# 223             practical      JJ
# 224            discipline      NN
# 225           encompasses     VBZ
# 226                   the      DT
# 227               methods     NNS
# 228                   and      CC
# 229              concepts     NNS
# 230                  that      IN
# 231             composers     NNS
# 232                   and      CC
# 233                 other      JJ
# 234             musicians     NNS
# 235                   use     VBP
# 236                    in      IN
# 237              creating     VBG
# 238                 music      NN
# 239                   the      DT
# 240           development      NN
# 241          preservation      NN
# 242                   and      CC
# 243          transmission      NN
# 244                    of      IN
# 245                 music      NN
# 246                theory      NN
# 247                    in      IN
# 248                  this      DT
# 249                 sense      NN
# 250                   may      MD
# 251                    be      VB
# 252                 found     VBN
# 253                    in      IN
# 254                  oral      JJ
# 255                   and      CC
# 256               written     VBN
# 257           musicmaking      JJ
# 258            traditions     NNS
# 259               musical      JJ
# 260           instruments     NNS
# 261                   and      CC
# 262                 other      JJ
# 263             artifacts     NNS
# 264                   for      IN
# 265               example      NN
# 266               ancient      JJ
# 267           instruments     NNS
# 268                  from      IN
# 269           prehistoric      JJ
# 270                 sites     NNS
# 271                around      IN
# 272                   the      DT
# 273                 world      NN
# 274                reveal      NN
# 275               details     NNS
# 276                 about      IN
# 277                   the      DT
# 278                 music      NN
# 279                  they     PRP
# 280              produced     VBD
# 281                   and      CC
# 282           potentially      RB
# 283             something      NN
# 284                    of      IN
# 285                   the      DT
# 286               musical      JJ
# 287                theory      NN
# 288                  that     WDT
# 289                 might      MD
# 290                  have      VB
# 291                  been     VBN
# 292                  used     VBN
# 293                    by      IN
# 294                 their    PRP$
# 295                makers     NNS
# 296                    in      IN
# 297               ancient      NN
# 298                   and      CC
# 299                living      NN
# 300              cultures     NNS
# 301                around      IN
# 302                   the      DT
# 303                 world      NN
# 304                   the      DT
# 305                  deep      JJ
# 306                   and      CC
# 307                  long      JJ
# 308                 roots     NNS
# 309                    of      IN
# 310                 music      NN
# 311                theory      NN
# 312                   are     VBP
# 313               visible      JJ
# 314                    in      IN
# 315           instruments     NNS
# 316                  oral      JJ
# 317            traditions     NNS
# 318                   and      CC
# 319               current      JJ
# 320           musicmaking     VBG
# 321                  many      JJ
# 322              cultures     NNS
# 323                  have     VBP
# 324                  also      RB
# 325            considered     VBN
# 326                 music      NN
# 327                theory      NN
# 328                    in      IN
# 329                  more     RBR
# 330                formal      JJ
# 331                  ways     NNS
# 332                  such      JJ
# 333                    as      IN
# 334               written     VBN
# 335             treatises     NNS
# 336                   and      CC
# 337                 music      NN
# 338              notation      NN
# 339             practical      JJ
# 340                   and      CC
# 341             scholarly      JJ
# 342            traditions     NNS
# 343               overlap     VBP
# 344                    as      IN
# 345                  many      JJ
# 346             practical      JJ
# 347             treatises     NNS
# 348                 about      IN
# 349                 music      NN
# 350                 place      NN
# 351            themselves     PRP
# 352                within      IN
# 353                     a      DT
# 354             tradition      NN
# 355                    of      IN
# 356                 other      JJ
# 357             treatises     NNS
# 358                 which     WDT
# 359                   are     VBP
# 360                 cited     VBN
# 361             regularly      RB
# 362                  just      RB
# 363                    as      IN
# 364             scholarly      JJ
# 365               writing      NN
# 366                 cites     NNS
# 367               earlier     RBR
# 368         researchmusic      JJ
# 369                    is     VBZ
# 370              composed     VBN
# 371                    of      IN
# 372                 aural      JJ
# 373             phenomena     NNS
# 374                 music      NN
# 375                theory      NN
# 376             considers     VBZ
# 377                   how     WRB
# 378                 those      DT
# 379             phenomena      JJ
# 380                 apply      NN
# 381                    in      IN
# 382                 music      NN
# 383                 music      NN
# 384                theory      NN
# 385             considers     NNS
# 386                melody     VBP
# 387                rhythm      JJ
# 388          counterpoint      NN
# 389               harmony      NN
# 390                  form     VBP
# 391                 tonal      JJ
# 392               systems     NNS
# 393                scales     VBZ
# 394                tuning     VBG
# 395             intervals     NNS
# 396            consonance      NN
# 397            dissonance      NN
# 398            durational      JJ
# 399           proportions     NNS
# 400                   the      DT
# 401             acoustics     NNS
# 402                    of      IN
# 403                 pitch      NN
# 404               systems     NNS
# 405           composition      NN
# 406           performance      NN
# 407         orchestration      NN
# 408         ornamentation      NN
# 409         improvisation      NN
# 410            electronic      JJ
# 411                 sound      NN
# 412            production      NN
# 413              etcpitch      NN
# 414                    is     VBZ
# 415                   the      DT
# 416               lowness      NN
# 417                    or      CC
# 418              highness      NN
# 419                    of      IN
# 420                     a      DT
# 421                  tone      NN
# 422                   for      IN
# 423               example      NN
# 424                   the      DT
# 425            difference      NN
# 426               between      IN
# 427                middle      JJ
# 428                     c      NN
# 429                   and      CC
# 430                     a      DT
# 431                higher     JJR
# 432                     c      NN
# 433                   the      DT
# 434             frequency      NN
# 435                    of      IN
# 436                   the      DT
# 437                 sound      NN
# 438                 waves     VBZ
# 439             producing     VBG
# 440                     a      DT
# 441                 pitch      NN
# 442                   can      MD
# 443                    be      VB
# 444              measured     VBN
# 445             precisely      RB
# 446                   but      CC
# 447                   the      DT
# 448            perception      NN
# 449                    of      IN
# 450                 pitch      NN
# 451                    is     VBZ
# 452                  more     RBR
# 453               complex      JJ
# 454               because      IN
# 455                single      JJ
# 456                 notes     NNS
# 457                  from      IN
# 458               natural      JJ
# 459               sources     NNS
# 460                   are     VBP
# 461               usually      RB
# 462                     a      DT
# 463               complex      JJ
# 464                   mix      NN
# 465                    of      IN
# 466                  many      JJ
# 467           frequencies     NNS
# 468           accordingly      RB
# 469             theorists     NNS
# 470                 often      RB
# 471              describe     VBP
# 472                 pitch      NN
# 473                    as      IN
# 474                     a      DT
# 475            subjective      JJ
# 476             sensation      NN
# 477                rather      RB
# 478                  than      IN
# 479                    an      DT
# 480             objective      JJ
# 481           measurement      NN
# 482                    of      IN
# 483         soundspecific      JJ
# 484           frequencies     NNS
# 485                   are     VBP
# 486                 often      RB
# 487              assigned      JJ
# 488                letter      NN
# 489                 names     NNS
# 490                 today      NN
# 491                  most     RBS
# 492            orchestras      JJ
# 493                assign      NN
# 494               concert      NN
# 495                     a      DT
# 496                   the      DT
# 497                     a      DT
# 498                 above      JJ
# 499                middle      NN
# 500                     c      NN
# 501                    on      IN
# 502                   the      DT
# 503                 piano      NN
# 504                    to      TO
# 505                   the      DT
# 506             frequency      NN
# 507                    of      IN
# 508                    hz      NN
# 509                  this      DT
# 510            assignment      NN
# 511                    is     VBZ
# 512              somewhat      RB
# 513             arbitrary      JJ
# 514                   for      IN
# 515               example      NN
# 516                    in      IN
# 517                france      NN
# 518                   the      DT
# 519                  same      JJ
# 520                     a      DT
# 521                   was     VBD
# 522                 tuned     VBN
# 523                    to      TO
# 524                    hz      VB
# 525                  such      JJ
# 526           differences     NNS
# 527                   can      MD
# 528                  have      VB
# 529                     a      DT
# 530            noticeable      JJ
# 531                effect      NN
# 532                    on      IN
# 533                   the      DT
# 534                timbre      NN
# 535                    of      IN
# 536           instruments     NNS
# 537                   and      CC
# 538                 other      JJ
# 539             phenomena     NNS
# 540                  thus      RB
# 541                    in      IN
# 542          historically      RB
# 543              informed     VBN
# 544           performance      NN
# 545                    of      IN
# 546                 older     JJR
# 547                 music      NN
# 548                tuning      NN
# 549                    is     VBZ
# 550                 often      RB
# 551                   set     VBN
# 552                    to      TO
# 553                 match      VB
# 554                   the      DT
# 555                tuning      NN
# 556                  used     VBN
# 557                    in      IN
# 558                   the      DT
# 559                period      NN
# 560                  when     WRB
# 561                    it     PRP
# 562                   was     VBD
# 563               written     VBN
# 564          additionally      RB
# 565                  many      JJ
# 566              cultures     NNS
# 567                    do     VBP
# 568                   not      RB
# 569               attempt      VB
# 570                    to      TO
# 571           standardize      VB
# 572                 pitch      NN
# 573                 often      RB
# 574           considering     VBG
# 575                  that      IN
# 576                    it     PRP
# 577                should      MD
# 578                    be      VB
# 579               allowed     VBN
# 580                    to      TO
# 581                  vary      VB
# 582             depending     VBG
# 583                    on      IN
# 584                 genre      JJ
# 585                 style      NN
# 586                  mood      NN
# 587                etcthe      JJ
# 588            difference      NN
# 589                    in      IN
# 590                 pitch      NN
# 591               between      IN
# 592                   two      CD
# 593                 notes     NNS
# 594                    is     VBZ
# 595                called     VBN
# 596                    an      DT
# 597              interval      NN
# 598                   the      DT
# 599                  most     RBS
# 600                 basic      JJ
# 601              interval      NN
# 602                    is     VBZ
# 603                   the      DT
# 604                unison      NN
# 605                 which     WDT
# 606                    is     VBZ
# 607                simply      RB
# 608                   two      CD
# 609                 notes     NNS
# 610                    of      IN
# 611                   the      DT
# 612                  same      JJ
# 613                 pitch      NN
# 614                   the      DT
# 615                octave      NN
# 616              interval      NN
# 617                    is     VBZ
# 618                   two      CD
# 619               pitches     NNS
# 620                  that     WDT
# 621                   are     VBP
# 622                either      DT
# 623                double      JJ
# 624                    or      CC
# 625                  half     PDT
# 626                   the      DT
# 627             frequency      NN
# 628                    of      IN
# 629                   one      CD
# 630               another      DT
# 631                   the      DT
# 632                unique      JJ
# 633       characteristics     NNS
# 634                    of      IN
# 635               octaves     NNS
# 636                  gave     VBD
# 637                  rise      NN
# 638                    to      TO
# 639                   the      DT
# 640               concept      NN
# 641                    of      IN
# 642                 pitch      NN
# 643                 class      NN
# 644               pitches     NNS
# 645                    of      IN
# 646                   the      DT
# 647                  same      JJ
# 648                letter      NN
# 649                  name      NN
# 650                  that     WDT
# 651                 occur     VBP
# 652                    in      IN
# 653             different      JJ
# 654               octaves     NNS
# 655                   may      MD
# 656                    be      VB
# 657               grouped     VBN
# 658                  into      IN
# 659                     a      DT
# 660                single      JJ
# 661                 class      NN
# 662                    by      IN
# 663              ignoring     VBG
# 664                   the      DT
# 665            difference      NN
# 666                    in      IN
# 667                octave      NN
# 668                   for      IN
# 669               example      NN
# 670                     a      DT
# 671                  high      JJ
# 672                     c      NN
# 673                   and      CC
# 674                     a      DT
# 675                   low      JJ
# 676                     c      NN
# 677                   are     VBP
# 678               members     NNS
# 679                    of      IN
# 680                   the      DT
# 681                  same      JJ
# 682                 pitch      NN
# 683             class—the      NN
# 684                 class      NN
# 685                  that     WDT
# 686              contains     VBZ
# 687                   all      DT
# 688                    cs      JJ
# 689               musical      JJ
# 690                tuning     VBG
# 691               systems     NNS
# 692                    or      CC
# 693          temperaments     NNS
# 694             determine     VBP
# 695                   the      DT
# 696               precise      JJ
# 697                  size      NN
# 698                    of      IN
# 699             intervals     NNS
# 700                tuning     VBG
# 701               systems     NNS
# 702                  vary     VBP
# 703                widely      RB
# 704                within      IN
# 705                   and      CC
# 706               between      IN
# 707                 world      NN
# 708              cultures     NNS
# 709                    in      IN
# 710               western      JJ
# 711               culture      NN
# 712                 there      EX
# 713                  have     VBP
# 714                  long      RB
# 715                  been     VBN
# 716               several      JJ
# 717             competing     VBG
# 718                tuning     VBG
# 719               systems     NNS
# 720                   all      DT
# 721                  with      IN
# 722             different      JJ
# 723             qualities     NNS
# 724       internationally      RB
# 725                   the      DT
# 726                system      NN
# 727                 known     VBN
# 728                    as      IN
# 729                 equal      JJ
# 730           temperament      NN
# 731                    is     VBZ
# 732                  most     RBS
# 733              commonly      RB
# 734                  used     VBN
# 735                 today      NN
# 736               because      IN
# 737                    it     PRP
# 738                    is     VBZ
# 739            considered     VBN
# 740                   the      DT
# 741                  most     RBS
# 742          satisfactory      JJ
# 743            compromise      NN
# 744                  that     WDT
# 745                allows     VBZ
# 746           instruments     NNS
# 747                    of      IN
# 748                 fixed      JJ
# 749                tuning     VBG
# 750                    eg      NN
# 751                   the      DT
# 752                 piano      NN
# 753                    to      TO
# 754                 sound      VB
# 755            acceptably      RB
# 756                    in      IN
# 757                  tune      NN
# 758                    in      IN
# 759                   all      DT
# 760             keysnotes     NNS
# 761                   can      MD
# 762                    be      VB
# 763              arranged     VBN
# 764                    in      IN
# 765                     a      DT
# 766               variety      NN
# 767                    of      IN
# 768                scales     NNS
# 769                   and      CC
# 770                 modes     NNS
# 771               western      JJ
# 772                 music      NN
# 773                theory      NN
# 774             generally      RB
# 775               divides     VBZ
# 776                   the      DT
# 777                octave      NN
# 778                  into      IN
# 779                     a      DT
# 780                series      NN
# 781                    of      IN
# 782                twelve      JJ
# 783               pitches     NNS
# 784                called     VBD
# 785                     a      DT
# 786             chromatic      JJ
# 787                 scale      NN
# 788                within      IN
# 789                 which     WDT
# 790                   the      DT
# 791              interval      NN
# 792               between      IN
# 793              adjacent      JJ
# 794                 tones     NNS
# 795                    is     VBZ
# 796                called     VBN
# 797                     a      DT
# 798                  half      JJ
# 799                  step      NN
# 800                    or      CC
# 801              semitone      NN
# 802             selecting     VBG
# 803                 tones     NNS
# 804                  from      IN
# 805                  this      DT
# 806                   set      NN
# 807                    of      IN
# 808                   and      CC
# 809             arranging     VBG
# 810                  them     PRP
# 811                    in      IN
# 812              patterns     NNS
# 813                    of      IN
# 814             semitones     NNS
# 815                   and      CC
# 816                 whole      JJ
# 817                 tones     NNS
# 818               creates     VBZ
# 819                 other      JJ
# 820         scalesmusical      JJ
# 821              notation      NN
# 822                    is     VBZ
# 823                   the      DT
# 824               written     VBN
# 825                    or      CC
# 826            symbolized     VBN
# 827        representation      NN
# 828                    of      IN
# 829                 music      NN
# 830                  this      DT
# 831                    is     VBZ
# 832                  most     RBS
# 833                 often      RB
# 834              achieved     VBN
# 835                    by      IN
# 836                   the      DT
# 837                   use      NN
# 838                    of      IN
# 839              commonly      RB
# 840            understood      JJ
# 841               graphic      JJ
# 842               symbols     NNS
# 843                   and      CC
# 844               written     VBN
# 845                verbal      JJ
# 846          instructions     NNS
# 847                   and      CC
# 848                 their    PRP$
# 849         abbreviations     NNS
# 850                 there      EX
# 851                   are     VBP
# 852                  many      JJ
# 853               systems     NNS
# 854                    of      IN
# 855                 music      NN
# 856              notation      NN
# 857                  from      IN
# 858             different      JJ
# 859              cultures     NNS
# 860                   and      CC
# 861             different      JJ
# 862                  ages     NNS
# 863           traditional      JJ
# 864               western      JJ
# 865              notation      NN
# 866               evolved     VBD
# 867                during      IN
# 868                   the      DT
# 869                middle      JJ
# 870                  ages     NNS
# 871                   and      CC
# 872               remains     VBZ
# 873                    an      DT
# 874                  area      NN
# 875                    of      IN
# 876       experimentation      NN
# 877                   and      CC
# 878          innovationin      VB
# 879                   the      DT
# 880                     s      JJ
# 881              computer      NN
# 882                  file      NN
# 883               formats     NNS
# 884                  have     VBP
# 885                become     VBN
# 886             important      JJ
# 887                    as      IN
# 888                  well      RB
# 889                spoken      JJ
# 890              language      NN
# 891                   and      CC
# 892                  hand      NN
# 893                 signs     NNS
# 894                   are     VBP
# 895                  also      RB
# 896                  used     VBN
# 897                    to      TO
# 898          symbolically      RB
# 899             represent      VB
# 900                 music      NN
# 901             primarily      RB
# 902                    in      IN
# 903            teachingin      JJ
# 904              standard      JJ
# 905               western      JJ
# 906                 music      NN
# 907              notation      NN
# 908                 tones     NNS
# 909                   are     VBP
# 910           represented     VBN
# 911           graphically      RB
# 912                    by      IN
# 913               symbols     NNS
# 914                 notes     NNS
# 915                placed     VBD
# 916                    on      IN
# 917                     a      DT
# 918                 staff      NN
# 919                    or      CC
# 920                staves     VBZ
# 921                   the      DT
# 922              vertical      JJ
# 923                  axis      NN
# 924         corresponding     VBG
# 925                    to      TO
# 926                 pitch      VB
# 927                   and      CC
# 928                   the      DT
# 929            horizontal      JJ
# 930                  axis      NN
# 931         corresponding     VBG
# 932                    to      TO
# 933                  time      NN
# 934                  note      NN
# 935                  head      NN
# 936                shapes     VBZ
# 937                 stems     VBZ
# 938                 flags      JJ
# 939                  ties     NNS
# 940                   and      CC
# 941                  dots     NNS
# 942                   are     VBP
# 943                  used     VBN
# 944                    to      TO
# 945              indicate      VB
# 946              duration      NN
# 947            additional      JJ
# 948               symbols     NNS
# 949              indicate     VBP
# 950                  keys     NNS
# 951              dynamics     NNS
# 952               accents     NNS
# 953                 rests     NNS
# 954                   etc     VBP
# 955                verbal      JJ
# 956          instructions     NNS
# 957                  from      IN
# 958                   the      DT
# 959             conductor      NN
# 960                   are     VBP
# 961                 often      RB
# 962                  used     VBN
# 963                    to      TO
# 964              indicate      VB
# 965                 tempo      NN
# 966             technique      NN
# 967                   and      CC
# 968                 other      JJ
# 969             aspectsin      NN
# 970               western      JJ
# 971                 music      NN
# 972                     a      DT
# 973                 range      NN
# 974                    of      IN
# 975             different      JJ
# 976                 music      NN
# 977              notation      NN
# 978               systems     NNS
# 979                   are     VBP
# 980                  used     VBN
# 981                    in      IN
# 982               western      JJ
# 983             classical      JJ
# 984                 music      NN
# 985            conductors     NNS
# 986                   use     VBP
# 987               printed      JJ
# 988                scores     NNS
# 989                  that     WDT
# 990                  show     VBP
# 991                   all      DT
# 992                    of      IN
# 993                   the      DT
# 994           instruments     NNS
# 995                 parts     NNS
# 996                   and      CC
# 997             orchestra      JJ
# 998               members     NNS
# 999                  read     VBP
# 1000                parts     NNS
# 1001                 with      IN
# 1002                their    PRP$
# 1003              musical      JJ
# 1004                lines     NNS
# 1005              written     VBN
# 1006                  out      RP
# 1007                   in      IN
# 1008              popular      JJ
# 1009               styles     NNS
# 1010                   of      IN
# 1011                music      NN
# 1012                 much      JJ
# 1013                 less     JJR
# 1014                   of      IN
# 1015                  the      DT
# 1016                music      NN
# 1017                  may      MD
# 1018                   be      VB
# 1019              notated     VBN
# 1020                    a      DT
# 1021                 rock      NN
# 1022                 band      NN
# 1023                  may      MD
# 1024                   go      VB
# 1025                 into      IN
# 1026                    a      DT
# 1027            recording      NN
# 1028              session      NN
# 1029                 with      IN
# 1030                 just      RB
# 1031                    a      DT
# 1032          handwritten      JJ
# 1033                chord      NN
# 1034                chart      NN
# 1035           indicating     VBG
# 1036                  the      DT
# 1037                songs     NNS
# 1038                chord      NN
# 1039          progression      NN
# 1040                using     VBG
# 1041                chord      NN
# 1042                names     NNS
# 1043                   eg     VBP
# 1044                    c      JJ
# 1045                major      JJ
# 1046                    d      NN
# 1047                minor      JJ
# 1048                    g      NN
# 1049                  etc      IN
# 1050                  all      DT
# 1051                   of      IN
# 1052                  the      DT
# 1053                chord      NN
# 1054             voicings     VBZ
# 1055              rhythms      NN
# 1056                  and      CC
# 1057        accompaniment      NN
# 1058              figures     NNS
# 1059                  are     VBP
# 1060           improvised     VBN
# 1061                   by      IN
# 1062                  the      DT
# 1063                 band      NN
# 1064         membersjapan     VBZ
# 1065             japanese      JJ
# 1066                   日本     NNP
# 1067               nippon      NN
# 1068                   or      CC
# 1069              nihonnb      NN
# 1070                  and      CC
# 1071             formally      RB
# 1072                  日本国      JJ
# 1073          nihonkokunb      NN
# 1074                   is     VBZ
# 1075                   an      DT
# 1076               island      JJ
# 1077              country      NN
# 1078                   in      IN
# 1079                 east      JJ
# 1080                 asia      NN
# 1081                   it     PRP
# 1082                   is     VBZ
# 1083             situated     VBN
# 1084                   in      IN
# 1085                  the      DT
# 1086            northwest     JJS
# 1087              pacific      JJ
# 1088                ocean      NN
# 1089                  and      CC
# 1090                   is     VBZ
# 1091             bordered     VBN
# 1092                   on      IN
# 1093                  the      DT
# 1094                 west      NN
# 1095                   by      IN
# 1096                  the      DT
# 1097                  sea      NN
# 1098                   of      IN
# 1099                japan      NN
# 1100                while      IN
# 1101            extending     VBG
# 1102                 from      IN
# 1103                  the      DT
# 1104                  sea      NN
# 1105                   of      IN
# 1106              okhotsk      NN
# 1107                   in      IN
# 1108                  the      DT
# 1109                north      JJ
# 1110               toward      IN
# 1111                  the      DT
# 1112                 east      JJ
# 1113                china      NN
# 1114                  sea      NN
# 1115           philippine      JJ
# 1116                  sea      NN
# 1117                  and      CC
# 1118               taiwan      NN
# 1119                   in      IN
# 1120                  the      DT
# 1121                south      JJ
# 1122                japan      NN
# 1123                   is     VBZ
# 1124                    a      DT
# 1125                 part      NN
# 1126                   of      IN
# 1127                  the      DT
# 1128                 ring      NN
# 1129                   of      IN
# 1130                 fire      NN
# 1131                  and      CC
# 1132                spans     VBZ
# 1133                   an      DT
# 1134          archipelago      NN
# 1135                   of      IN
# 1136              islands     NNS
# 1137             covering     VBG
# 1138               square      JJ
# 1139           kilometers     NNS
# 1140                   sq     VBP
# 1141                   mi     PDT
# 1142                  the      DT
# 1143                 five      CD
# 1144                 main      JJ
# 1145              islands     NNS
# 1146                  are     VBP
# 1147             hokkaido      JJ
# 1148               honshu      IN
# 1149                  the      DT
# 1150             mainland      NN
# 1151              shikoku      NN
# 1152               kyushu      NN
# 1153                  and      CC
# 1154              okinawa      JJ
# 1155                tokyo      NN
# 1156                   is     VBZ
# 1157                  the      DT
# 1158              nations     NNS
# 1159              capital      NN
# 1160                  and      CC
# 1161              largest     JJS
# 1162                 city      NN
# 1163             followed     VBN
# 1164                   by      IN
# 1165             yokohama      NN
# 1166                osaka      NN
# 1167               nagoya      JJ
# 1168              sapporo      NN
# 1169              fukuoka      NN
# 1170                 kobe      NN
# 1171                  and      CC
# 1172           kyotojapan      NN
# 1173                   is     VBZ
# 1174                  the      DT
# 1175             eleventh      JJ
# 1176                 most     RBS
# 1177             populous      JJ
# 1178              country      NN
# 1179                   in      IN
# 1180                  the      DT
# 1181                world      NN
# 1182                   as      RB
# 1183                 well      RB
# 1184                   as      IN
# 1185                  one      CD
# 1186                   of      IN
# 1187                  the      DT
# 1188                 most     RBS
# 1189              densely      RB
# 1190            populated      JJ
# 1191                  and      CC
# 1192            urbanized      JJ
# 1193                about      IN
# 1194         threefourths     NNS
# 1195                   of      IN
# 1196                  the      DT
# 1197             countrys      NN
# 1198              terrain      NN
# 1199                   is     VBZ
# 1200          mountainous      JJ
# 1201        concentrating     VBG
# 1202                  its    PRP$
# 1203           population      NN
# 1204                   of      IN
# 1205              million      CD
# 1206                   on      IN
# 1207               narrow      JJ
# 1208              coastal      JJ
# 1209               plains     NNS
# 1210                japan      NN
# 1211                   is     VBZ
# 1212              divided     VBN
# 1213                 into      IN
# 1214       administrative      JJ
# 1215          prefectures     NNS
# 1216                  and      CC
# 1217                eight      CD
# 1218          traditional      JJ
# 1219              regions     NNS
# 1220                  the      DT
# 1221              greater     JJR
# 1222                tokyo      JJ
# 1223                 area      NN
# 1224                   is     VBZ
# 1225                  the      DT
# 1226                 most     RBS
# 1227             populous      JJ
# 1228         metropolitan      JJ
# 1229                 area      NN
# 1230                   in      IN
# 1231                  the      DT
# 1232                world      NN
# 1233                 with      IN
# 1234                 more     JJR
# 1235                 than      IN
# 1236              million      CD
# 1237       residentsjapan      NN
# 1238                  has     VBZ
# 1239                 been     VBN
# 1240            inhabited     VBN
# 1241                since      IN
# 1242                  the      DT
# 1243                upper      JJ
# 1244          paleolithic      JJ
# 1245               period      NN
# 1246                   bc      IN
# 1247               though      IN
# 1248                  the      DT
# 1249                first      JJ
# 1250              written     VBN
# 1251              mention      NN
# 1252                   of      IN
# 1253                  the      DT
# 1254          archipelago      NN
# 1255              appears     VBZ
# 1256                   in      IN
# 1257                    a      DT
# 1258              chinese      JJ
# 1259            chronicle      NN
# 1260                  the      DT
# 1261                 book      NN
# 1262                   of      IN
# 1263                  han      NN
# 1264             finished     VBN
# 1265                   in      IN
# 1266                  the      DT
# 1267                   nd      JJ
# 1268              century      NN
# 1269                   ad      NN
# 1270              between      IN
# 1271                  the      DT
# 1272                   th      NN
# 1273                  and      CC
# 1274                   th      NN
# 1275            centuries     NNS
# 1276                  the      DT
# 1277             kingdoms     NNS
# 1278                   of      IN
# 1279                japan      NN
# 1280               became     VBD
# 1281              unified      JJ
# 1282                under      IN
# 1283                   an      DT
# 1284              emperor      NN
# 1285                  and      CC
# 1286                  the      DT
# 1287             imperial      JJ
# 1288                court      NN
# 1289                based     VBN
# 1290                   in      IN
# 1291             heiankyō      NN
# 1292            beginning      NN
# 1293                   in      IN
# 1294                  the      DT
# 1295                   th      JJ
# ...
# 3098                         noun, singular (cat, tree)
# 3099              preposition/subordinating conjunction
# 3100                                         determiner
# 3101          This NLTK POS Tag is an adjective (large)
# 3102                                noun plural (desks)
# 3103              preposition/subordinating conjunction
# 3104                                         determiner
# 3105                         noun, singular (cat, tree)
# 3106              preposition/subordinating conjunction
# 3107                         noun, singular (cat, tree)
# 3108                         noun, singular (cat, tree)
# 3109                          verb past tense (pleaded)
# 3110                         noun, singular (cat, tree)
# 3111                               infinite marker (to)
# 3112                                         verb (ask)
# 3113                                         determiner
# 3114                   adjective, superlative (largest)
# 3115                         noun, singular (cat, tree)
# 3116              preposition/subordinating conjunction
# 3117                                         determiner
# 3118                         noun, singular (cat, tree)
# 3119                                         determiner
# 3120                   verb past participle (reunified)
# 3121              preposition/subordinating conjunction
# 3122                                         determiner
# 3123                                noun plural (desks)
# 3124              preposition/subordinating conjunction
# 3125                                         determiner
# 3126                         noun, singular (cat, tree)
# 3127              preposition/subordinating conjunction
# 3128                                         determiner
# 3129                         noun, singular (cat, tree)
# 3130                         noun, singular (cat, tree)
# 3131          This NLTK POS Tag is an adjective (large)
# 3132                              verb gerund (judging)
# 3133                                         determiner
# 3134                   verb past participle (reunified)
# 3135                         noun, singular (cat, tree)
# 3136              preposition/subordinating conjunction
# 3137                         noun, singular (cat, tree)
# 3138                         noun, singular (cat, tree)
# 3139                          verb past tense (pleaded)
# 3140                                     cardinal digit
# 3141              preposition/subordinating conjunction
# 3142                                         determiner
# 3143                   adjective, superlative (largest)
# 3144                                noun plural (desks)
# 3145              preposition/subordinating conjunction
# 3146       possessive pronoun (her, his, mine, my, our)
# 3147          This NLTK POS Tag is an adjective (large)
# 3148                         noun, singular (cat, tree)
# 3149                              verb gerund (judging)
# 3150                                         determiner
# 3151                         noun, singular (cat, tree)
# 3152          This NLTK POS Tag is an adjective (large)
# 3153          This NLTK POS Tag is an adjective (large)
# 3154                         noun, singular (cat, tree)
# 3155              preposition/subordinating conjunction
# 3156                                modal (could, will)
# 3157              preposition/subordinating conjunction
# 3158                                         determiner
# 3159          This NLTK POS Tag is an adjective (large)
# 3160                         noun, singular (cat, tree)
# 3161              preposition/subordinating conjunction
# 3162                         noun, singular (cat, tree)
# 3163              preposition/subordinating conjunction
# 3164       possessive pronoun (her, his, mine, my, our)
# 3165                         noun, singular (cat, tree)
# 3166                         noun, singular (cat, tree)
# 3167                          verb past tense (pleaded)
# 3168          This NLTK POS Tag is an adjective (large)
# 3169                              verb gerund (judging)
# 3170                                         determiner
# 3171                         noun, singular (cat, tree)
# 3172                         noun, singular (cat, tree)
# 3173  verb, present tense with 3rd person singular (...
# 3174                                noun plural (desks)
# 3175                              verb gerund (judging)
# 3176              preposition/subordinating conjunction
# 3177                                         determiner
# 3178          This NLTK POS Tag is an adjective (large)
# 3179                         noun, singular (cat, tree)
# 3180              preposition/subordinating conjunction
# 3181                         noun, singular (cat, tree)
# 3182     personal pronoun (hers, herself, him, himself)
# 3183  verb, present tense with 3rd person singular (...
# 3184              preposition/subordinating conjunction
# 3185                                       foreign word
# 3186          This NLTK POS Tag is an adjective (large)
# 3187                   adjective, superlative (largest)
# 3188              preposition/subordinating conjunction
# 3189                                         determiner
# 3190                         noun, singular (cat, tree)
# 3191              preposition/subordinating conjunction
# 3192                         noun, singular (cat, tree)
# 3193                               infinite marker (to)
# 3194                                         determiner
# 3195          This NLTK POS Tag is an adjective (large)
# 3196                         noun, singular (cat, tree)
# 3197                          verb past tense (pleaded)
# 3198                                         determiner
# 3199                         noun, singular (cat, tree)
# 3200                                     cardinal digit
# 3201          This NLTK POS Tag is an adjective (large)
# 3202                                noun plural (desks)
# 3203              preposition/subordinating conjunction
# 3204          This NLTK POS Tag is an adjective (large)
# 3205                               infinite marker (to)
# 3206                                noun plural (desks)
# 3207  verb, present tense not 3rd person singular (w...
# 3208          This NLTK POS Tag is an adjective (large)
# 3209          This NLTK POS Tag is an adjective (large)
# 3210                         noun, singular (cat, tree)
# 3211                         noun, singular (cat, tree)
# 3212                           coordinating conjunction
# 3213                                         verb (ask)
# 3214                                         determiner
# 3215                         noun, singular (cat, tree)
# 3216  verb, present tense with 3rd person singular (...
# 3217                         wh-determiner (that, what)
# 3218  verb, present tense not 3rd person singular (w...
# 3219                                noun plural (desks)
# 3220  verb, present tense not 3rd person singular (w...
# 3221                                         determiner
# 3222                         noun, singular (cat, tree)
# 3223                               infinite marker (to)
# 3224                                         determiner
# 3225                         noun, singular (cat, tree)
# 3226              preposition/subordinating conjunction
# 3227                         noun, singular (cat, tree)
# 3228                                         determiner
# 3229          This NLTK POS Tag is an adjective (large)
# 3230                                noun plural (desks)
# 3231  verb, present tense not 3rd person singular (w...
# 3232          This NLTK POS Tag is an adjective (large)
# 3233                           coordinating conjunction
# 3234                         noun, singular (cat, tree)
# 3235              preposition/subordinating conjunction
# 3236                                         determiner
# 3237          This NLTK POS Tag is an adjective (large)
# 3238                                noun plural (desks)
# 3239              preposition/subordinating conjunction
# 3240                         noun, singular (cat, tree)
# 3241                     adverb (occasionally, swiftly)
# 3242     personal pronoun (hers, herself, him, himself)
# 3243  verb, present tense not 3rd person singular (w...
# 3244                     adverb (occasionally, swiftly)
# 3245                   verb past participle (reunified)
# 3246              preposition/subordinating conjunction
# 3247                                         determiner
# 3248          This NLTK POS Tag is an adjective (large)
# 3249                         noun, singular (cat, tree)
# 3250              preposition/subordinating conjunction
# 3251              preposition/subordinating conjunction
# 3252                                noun plural (desks)
# 3253                         noun, singular (cat, tree)
# 3254  verb, present tense with 3rd person singular (...
# 3255          This NLTK POS Tag is an adjective (large)
# 3256                         noun, singular (cat, tree)
# 3257                         noun, singular (cat, tree)
# 3258                         noun, singular (cat, tree)
# 3259  verb, present tense with 3rd person singular (...
# 3260                                         determiner
# 3261                   adjective, superlative (largest)
# 3262                         noun, singular (cat, tree)
# 3263              preposition/subordinating conjunction
# 3264                                         determiner
# 3265                         noun, singular (cat, tree)
# 3266              preposition/subordinating conjunction
# 3267                         noun, singular (cat, tree)
# 3268                         noun, singular (cat, tree)
# 3269              preposition/subordinating conjunction
# 3270              preposition/subordinating conjunction
# 3271       possessive pronoun (her, his, mine, my, our)
# 3272                         noun, singular (cat, tree)
# 3273                              verb gerund (judging)
# 3274                                noun plural (desks)
# 3275                         noun, singular (cat, tree)
# 3276  verb, present tense with 3rd person singular (...
# 3277                                         determiner
# 3278          This NLTK POS Tag is an adjective (large)
# 3279                   adjective, superlative (largest)
# 3280          This NLTK POS Tag is an adjective (large)
# 3281          This NLTK POS Tag is an adjective (large)
# 3282                         noun, singular (cat, tree)
# 3283              preposition/subordinating conjunction
# 3284                                         determiner
# 3285                         noun, singular (cat, tree)
# 3286                              verb gerund (judging)
# 3287          This NLTK POS Tag is an adjective (large)
# 3288                         noun, singular (cat, tree)
# 3289  verb, present tense with 3rd person singular (...
# 3290          This NLTK POS Tag is an adjective (large)
# 3291                         noun, singular (cat, tree)
# 3292  verb, present tense with 3rd person singular (...
# 3293                                noun plural (desks)
# 3294                           coordinating conjunction
# 3295          This NLTK POS Tag is an adjective (large)
# 3296                                         determiner
# 3297                     adverb (occasionally, swiftly)
# 3298                   verb past participle (reunified)
# 3299                           coordinating conjunction
# 3300          This NLTK POS Tag is an adjective (large)
# 3301                         noun, singular (cat, tree)
# 3302  verb, present tense with 3rd person singular (...
# 3303                   verb past participle (reunified)
# 3304              preposition/subordinating conjunction
# 3305                         noun, singular (cat, tree)
# 3306                     adverb (occasionally, swiftly)
# 3307                                         determiner
# 3308          This NLTK POS Tag is an adjective (large)
# 3309                                noun plural (desks)
# 3310                     adverb (occasionally, swiftly)
# 3311              preposition/subordinating conjunction
# 3312                                         determiner
# 3313          This NLTK POS Tag is an adjective (large)
# 3314                                noun plural (desks)
# 3315  verb, present tense not 3rd person singular (w...
# 3316                     adverb (occasionally, swiftly)
# 3317          This NLTK POS Tag is an adjective (large)
# 3318                         noun, singular (cat, tree)
# 3319                                noun plural (desks)
# 3320  verb, present tense not 3rd person singular (w...
# 3321  verb, present tense with 3rd person singular (...
# 3322                                         determiner
# 3323                         noun, singular (cat, tree)
# 3324                      adverb, superlative (biggest)
# 3325                     adverb (occasionally, swiftly)
# 3326          This NLTK POS Tag is an adjective (large)
# 3327                         noun, singular (cat, tree)
# 3328                         noun, singular (cat, tree)
# 3329  verb, present tense with 3rd person singular (...
# 3330                                         determiner
# 3331                   adjective, superlative (largest)
# 3332                         noun, singular (cat, tree)
# 3333                         noun, singular (cat, tree)
# 3334              preposition/subordinating conjunction
# 3335                         noun, singular (cat, tree)
# 3336                         noun, singular (cat, tree)
# 3337                         noun, singular (cat, tree)
# 3338              preposition/subordinating conjunction
# 3339              preposition/subordinating conjunction
# 3340              preposition/subordinating conjunction
# 3341                         noun, singular (cat, tree)
# 3342  verb, present tense with 3rd person singular (...
# 3343                                         determiner
# 3344                   adjective, superlative (largest)
# 3345                         noun, singular (cat, tree)
# 3346              preposition/subordinating conjunction
# 3347                         noun, singular (cat, tree)
# 3348              preposition/subordinating conjunction
# 3349              preposition/subordinating conjunction
# 3350              preposition/subordinating conjunction
# 3351              preposition/subordinating conjunction
# 3352                     adverb (occasionally, swiftly)
# 3353              preposition/subordinating conjunction
# 3354                                noun plural (desks)
# 3355          This NLTK POS Tag is an adjective (large)
# 3356                         noun, singular (cat, tree)
# 3357  verb, present tense with 3rd person singular (...
# 3358                   verb past participle (reunified)
# 3359                         noun, singular (cat, tree)
# 3360          This NLTK POS Tag is an adjective (large)
# 3361                         noun, singular (cat, tree)
# 3362                         noun, singular (cat, tree)
# 3363  verb, present tense with 3rd person singular (...
# 3364                                         determiner
# 3365          This NLTK POS Tag is an adjective (large)
# 3366                         noun, singular (cat, tree)
# 3367                           coordinating conjunction
# 3368                                         determiner
# 3369                         noun, singular (cat, tree)
# 3370                   adjective, superlative (largest)
# 3371                         noun, singular (cat, tree)
# 3372                         noun, singular (cat, tree)
